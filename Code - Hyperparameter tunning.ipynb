# %% [markdown]
# # Libraries and Functions

# %%
#Importing libraries
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
pd.options.display.max_rows = 999
import warnings
warnings.filterwarnings("ignore")
import sys
sys.dont_write_bytecode = True
#importing datasets
from src.New_Utils import New_Sequences
from Datasets import Replace
from Datasets import AIDE
from Datasets import Shanghai
#Libraries to run the experiments
from src.model import Model
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# %%
Model = Model()

# %%
def Run_Models(sequences, l1_penalty, l2_penalty, learning_rate, batch_size,  skf, Model):

    model = Model
    results = []

    # loop across the folds
    for i, (train_index, test_index) in enumerate(skf.split(X=[s['X'] for s in sequences], y=[s['Y'] for s in sequences])):
        
        # fit the model to the training set


        model.fit(
            sequences=[sequences[i] for i in train_index],
            sequence_length=int(7 * 24 * 60 // 5),
            l1_penalty=l1_penalty,
            l2_penalty=l2_penalty,
            learning_rate=learning_rate,
            batch_size=batch_size,
            epochs=1000,
            seed=42,
            verbose=0
        )

        # evaluate the model on the test set
        metrics = model.evaluate(sequences=[sequences[i] for i in test_index])

        # save the results
        results.append(metrics)

    # organize the results in a data frame
    results = pd.DataFrame(results)

    return results.mean().values[6]

# %% [markdown]
# # Grid Search

# %%
Parameters =[[0.01, 0.01, 1e-06, 64]
,[0.01, 0.01, 1e-06, 32]
,[0.01, 0.01, 1e-06, 16]
,[0.01, 0.01, 1e-06, 128]
,[0.01, 0.01, 0.1, 64]
,[0.01, 0.01, 0.1, 32]
,[0.01, 0.01, 0.1, 16]
,[0.01, 0.01, 0.1, 128]
,[0.01, 0.01, 0.0001, 64]
,[0.01, 0.01, 0.0001, 32]
,[0.01, 0.01, 0.0001, 16]
,[0.01, 0.01, 0.0001, 128]
,[0.01, 0.001, 1e-06, 64]
,[0.01, 0.001, 1e-06, 32]
,[0.01, 0.001, 1e-06, 16]
,[0.01, 0.001, 1e-06, 128]
,[0.01, 0.001, 0.1, 64]
,[0.01, 0.001, 0.1, 32]
,[0.01, 0.001, 0.1, 16]
,[0.01, 0.001, 0.1, 128]
,[0.01, 0.001, 0.0001, 64]
,[0.01, 0.001, 0.0001, 32]
,[0.01, 0.001, 0.0001, 16]
,[0.01, 0.001, 0.0001, 128]
,[0.01, 0.0001, 1e-06, 64]
,[0.01, 0.0001, 1e-06, 32]
,[0.01, 0.0001, 1e-06, 16]
,[0.01, 0.0001, 1e-06, 128]
,[0.01, 0.0001, 0.1, 64]
,[0.01, 0.0001, 0.1, 32]
,[0.01, 0.0001, 0.1, 16]
,[0.01, 0.0001, 0.1, 128]
,[0.01, 0.0001, 0.0001, 64]
,[0.01, 0.0001, 0.0001, 32]
,[0.01, 0.0001, 0.0001, 16]
,[0.01, 0.0001, 0.0001, 128]
,[0.001, 0.01, 1e-06, 64]
,[0.001, 0.01, 1e-06, 32]
,[0.001, 0.01, 1e-06, 16]
,[0.001, 0.01, 1e-06, 128]
,[0.001, 0.01, 0.1, 64]
,[0.001, 0.01, 0.1, 32]
,[0.001, 0.01, 0.1, 16]
,[0.001, 0.01, 0.1, 128]
,[0.001, 0.01, 0.0001, 64]
,[0.001, 0.01, 0.0001, 32]
,[0.001, 0.01, 0.0001, 16]
,[0.001, 0.01, 0.0001, 128]
,[0.001, 0.001, 1e-06, 64]
,[0.001, 0.001, 1e-06, 32]
,[0.001, 0.001, 1e-06, 16]
,[0.001, 0.001, 1e-06, 128]
,[0.001, 0.001, 0.1, 64]
,[0.001, 0.001, 0.1, 32]
,[0.001, 0.001, 0.1, 16]
,[0.001, 0.001, 0.1, 128]
,[0.001, 0.001, 0.0001, 64]
,[0.001, 0.001, 0.0001, 32]
,[0.001, 0.001, 0.0001, 16]
,[0.001, 0.001, 0.0001, 128]
,[0.001, 0.0001, 1e-06, 64]
,[0.001, 0.0001, 1e-06, 32]
,[0.001, 0.0001, 1e-06, 16]
,[0.001, 0.0001, 1e-06, 128]
,[0.001, 0.0001, 0.1, 64]
,[0.001, 0.0001, 0.1, 32]
,[0.001, 0.0001, 0.1, 16]
,[0.001, 0.0001, 0.1, 128]
,[0.001, 0.0001, 0.0001, 64]
,[0.001, 0.0001, 0.0001, 32]
,[0.001, 0.0001, 0.0001, 16]
,[0.001, 0.0001, 0.0001, 128]
,[0.0001, 0.01, 1e-06, 64]
,[0.0001, 0.01, 1e-06, 32]
,[0.0001, 0.01, 1e-06, 16]
,[0.0001, 0.01, 1e-06, 128]
,[0.0001, 0.01, 0.1, 64]
,[0.0001, 0.01, 0.1, 32]
,[0.0001, 0.01, 0.1, 16]
,[0.0001, 0.01, 0.1, 128]
,[0.0001, 0.01, 0.0001, 64]
,[0.0001, 0.01, 0.0001, 32]
,[0.0001, 0.01, 0.0001, 16]
,[0.0001, 0.01, 0.0001, 128]
,[0.0001, 0.001, 1e-06, 64]
,[0.0001, 0.001, 1e-06, 32]
,[0.0001, 0.001, 1e-06, 16]
,[0.0001, 0.001, 1e-06, 128]
,[0.0001, 0.001, 0.1, 64]
,[0.0001, 0.001, 0.1, 32]
,[0.0001, 0.001, 0.1, 16]
,[0.0001, 0.001, 0.1, 128]
,[0.0001, 0.001, 0.0001, 64]
,[0.0001, 0.001, 0.0001, 32]
,[0.0001, 0.001, 0.0001, 16]
,[0.0001, 0.001, 0.0001, 128]
,[0.0001, 0.0001, 1e-06, 64]
,[0.0001, 0.0001, 1e-06, 32]
,[0.0001, 0.0001, 1e-06, 16]
,[0.0001, 0.0001, 1e-06, 128]
,[0.0001, 0.0001, 0.1, 64]
,[0.0001, 0.0001, 0.1, 32]
,[0.0001, 0.0001, 0.1, 16]
,[0.0001, 0.0001, 0.1, 128]
,[0.0001, 0.0001, 0.0001, 64]
,[0.0001, 0.0001, 0.0001, 32]
,[0.0001, 0.0001, 0.0001, 16]
,[0.0001, 0.0001, 0.0001, 128]
]

# %% [markdown]
# ## Replace

# %%
sequences = New_Sequences(Replace)
Grid_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Grid_Search_Results = pd.concat([Grid_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Grid_Search_Results.sort_values(by='AUC', ascending=False)

# %% [markdown]
# ## AIDE

# %%
sequences = New_Sequences(AIDE)
Grid_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Grid_Search_Results = pd.concat([Grid_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Grid_Search_Results.sort_values(by='AUC', ascending=False)
# Out:
# Error con parámetros [0.01, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Empty DataFrame
# Columns: [Parameters, AUC]
# Index: []

# %% [markdown]
# # Shanghai

# %%
sequences = New_Sequences(Shanghai, minutes=15)
Grid_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Grid_Search_Results = pd.concat([Grid_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Grid_Search_Results.sort_values(by='AUC', ascending=False)
# Out:
#                         Parameters       AUC
# 102      [0.0001, 0.0001, 0.1, 16]      0.75
# 54         [0.001, 0.001, 0.1, 16]  0.714286
# 66        [0.001, 0.0001, 0.1, 16]  0.702381
# 7           [0.01, 0.01, 0.1, 128]  0.690476
# 4            [0.01, 0.01, 0.1, 64]  0.690476
# 5            [0.01, 0.01, 0.1, 32]  0.690476
# 42          [0.001, 0.01, 0.1, 16]  0.613095
# 67       [0.001, 0.0001, 0.1, 128]  0.607143
# 64        [0.001, 0.0001, 0.1, 64]  0.607143
# 65        [0.001, 0.0001, 0.1, 32]  0.607143
# 105   [0.0001, 0.0001, 0.0001, 32]  0.595238
# 44       [0.001, 0.01, 0.0001, 64]  0.595238
# 45       [0.001, 0.01, 0.0001, 32]  0.595238
# 47      [0.001, 0.01, 0.0001, 128]  0.595238
# 52         [0.001, 0.001, 0.1, 64]  0.595238
# 53         [0.001, 0.001, 0.1, 32]  0.595238
# 55        [0.001, 0.001, 0.1, 128]  0.595238
# 56      [0.001, 0.001, 0.0001, 64]  0.595238
# 57      [0.001, 0.001, 0.0001, 32]  0.595238
# 59     [0.001, 0.001, 0.0001, 128]  0.595238
# 104   [0.0001, 0.0001, 0.0001, 64]  0.595238
# 95    [0.0001, 0.001, 0.0001, 128]  0.595238
# 68     [0.001, 0.0001, 0.0001, 64]  0.595238
# 69     [0.001, 0.0001, 0.0001, 32]  0.595238
# 35     [0.01, 0.0001, 0.0001, 128]  0.595238
# 80      [0.0001, 0.01, 0.0001, 64]  0.595238
# 81      [0.0001, 0.01, 0.0001, 32]  0.595238
# 83     [0.0001, 0.01, 0.0001, 128]  0.595238
# 88        [0.0001, 0.001, 0.1, 64]  0.595238
# 89        [0.0001, 0.001, 0.1, 32]  0.595238
# 91       [0.0001, 0.001, 0.1, 128]  0.595238
# 92     [0.0001, 0.001, 0.0001, 64]  0.595238
# 93     [0.0001, 0.001, 0.0001, 32]  0.595238
# 71    [0.001, 0.0001, 0.0001, 128]  0.595238
# 107  [0.0001, 0.0001, 0.0001, 128]  0.595238
# 9         [0.01, 0.01, 0.0001, 32]  0.595238
# 8         [0.01, 0.01, 0.0001, 64]  0.595238
# 18          [0.01, 0.001, 0.1, 16]  0.595238
# 20       [0.01, 0.001, 0.0001, 64]  0.595238
# 21       [0.01, 0.001, 0.0001, 32]  0.595238
# 23      [0.01, 0.001, 0.0001, 128]  0.595238
# 33      [0.01, 0.0001, 0.0001, 32]  0.595238
# 32      [0.01, 0.0001, 0.0001, 64]  0.595238
# 11       [0.01, 0.01, 0.0001, 128]  0.595238
# 30         [0.01, 0.0001, 0.1, 16]  0.583333
# 22       [0.01, 0.001, 0.0001, 16]  0.559524
# 90        [0.0001, 0.001, 0.1, 16]  0.559524
# 10        [0.01, 0.01, 0.0001, 16]  0.559524
# 34      [0.01, 0.0001, 0.0001, 16]  0.559524
# 103     [0.0001, 0.0001, 0.1, 128]  0.559524
# 101      [0.0001, 0.0001, 0.1, 32]  0.559524
# 100      [0.0001, 0.0001, 0.1, 64]  0.559524
# 79        [0.0001, 0.01, 0.1, 128]  0.541667
# 77         [0.0001, 0.01, 0.1, 32]  0.541667
# 76         [0.0001, 0.01, 0.1, 64]  0.541667
# 6            [0.01, 0.01, 0.1, 16]   0.52381
# 58      [0.001, 0.001, 0.0001, 16]   0.52381
# 46       [0.001, 0.01, 0.0001, 16]   0.52381
# 70     [0.001, 0.0001, 0.0001, 16]   0.52381
# 31        [0.01, 0.0001, 0.1, 128]  0.494048
# 28         [0.01, 0.0001, 0.1, 64]  0.494048
# 29         [0.01, 0.0001, 0.1, 32]  0.494048
# 94     [0.0001, 0.001, 0.0001, 16]  0.488095
# 106   [0.0001, 0.0001, 0.0001, 16]  0.488095
# 82      [0.0001, 0.01, 0.0001, 16]  0.488095
# 14        [0.01, 0.001, 1e-06, 16]   0.47619
# 84      [0.0001, 0.001, 1e-06, 64]   0.47619
# 85      [0.0001, 0.001, 1e-06, 32]   0.47619
# 86      [0.0001, 0.001, 1e-06, 16]   0.47619
# 99    [0.0001, 0.0001, 1e-06, 128]   0.47619
# 87     [0.0001, 0.001, 1e-06, 128]   0.47619
# 2          [0.01, 0.01, 1e-06, 16]   0.47619
# 3         [0.01, 0.01, 1e-06, 128]   0.47619
# 98     [0.0001, 0.0001, 1e-06, 16]   0.47619
# 13        [0.01, 0.001, 1e-06, 32]   0.47619
# 12        [0.01, 0.001, 1e-06, 64]   0.47619
# 96     [0.0001, 0.0001, 1e-06, 64]   0.47619
# 97     [0.0001, 0.0001, 1e-06, 32]   0.47619
# 15       [0.01, 0.001, 1e-06, 128]   0.47619
# 0          [0.01, 0.01, 1e-06, 64]   0.47619
# 26       [0.01, 0.0001, 1e-06, 16]   0.47619
# 60      [0.001, 0.0001, 1e-06, 64]   0.47619
# 48       [0.001, 0.001, 1e-06, 64]   0.47619
# 49       [0.001, 0.001, 1e-06, 32]   0.47619
# 50       [0.001, 0.001, 1e-06, 16]   0.47619
# 51      [0.001, 0.001, 1e-06, 128]   0.47619
# 1          [0.01, 0.01, 1e-06, 32]   0.47619
# 27      [0.01, 0.0001, 1e-06, 128]   0.47619
# 38        [0.001, 0.01, 1e-06, 16]   0.47619
# 25       [0.01, 0.0001, 1e-06, 32]   0.47619
# 39       [0.001, 0.01, 1e-06, 128]   0.47619
# 24       [0.01, 0.0001, 1e-06, 64]   0.47619
# 61      [0.001, 0.0001, 1e-06, 32]   0.47619
# 62      [0.001, 0.0001, 1e-06, 16]   0.47619
# 63     [0.001, 0.0001, 1e-06, 128]   0.47619
# 37        [0.001, 0.01, 1e-06, 32]   0.47619
# 36        [0.001, 0.01, 1e-06, 64]   0.47619
# 72       [0.0001, 0.01, 1e-06, 64]   0.47619
# 73       [0.0001, 0.01, 1e-06, 32]   0.47619
# 74       [0.0001, 0.01, 1e-06, 16]   0.47619
# 75      [0.0001, 0.01, 1e-06, 128]   0.47619
# 43         [0.001, 0.01, 0.1, 128]  0.416667
# 41          [0.001, 0.01, 0.1, 32]  0.416667
# 40          [0.001, 0.01, 0.1, 64]  0.416667
# 16          [0.01, 0.001, 0.1, 64]  0.410714
# 19         [0.01, 0.001, 0.1, 128]  0.410714
# 17          [0.01, 0.001, 0.1, 32]  0.410714
# 78         [0.0001, 0.01, 0.1, 16]  0.363095

# %% [markdown]
# # Random Search

# %%
Parameter = [[0.9447, 0.7984, 0.9425, 64]
,[0.9447, 0.7984, 0.9425, 32]
,[0.9447, 0.7984, 0.9425, 16]
,[0.9447, 0.7984, 0.9425, 128]
,[0.9447, 0.7984, 0.3126, 64]
,[0.9447, 0.7984, 0.3126, 32]
,[0.9447, 0.7984, 0.3126, 16]
,[0.9447, 0.7984, 0.3126, 128]
,[0.9447, 0.7984, 0.0916, 64]
,[0.9447, 0.7984, 0.0916, 32]
,[0.9447, 0.7984, 0.0916, 16]
,[0.9447, 0.7984, 0.0916, 128]
,[0.9447, 0.5364, 0.9425, 64]
,[0.9447, 0.5364, 0.9425, 32]
,[0.9447, 0.5364, 0.9425, 16]
,[0.9447, 0.5364, 0.9425, 128]
,[0.9447, 0.5364, 0.3126, 64]
,[0.9447, 0.5364, 0.3126, 32]
,[0.9447, 0.5364, 0.3126, 16]
,[0.9447, 0.5364, 0.3126, 128]
,[0.9447, 0.5364, 0.0916, 64]
,[0.9447, 0.5364, 0.0916, 32]
,[0.9447, 0.5364, 0.0916, 16]
,[0.9447, 0.5364, 0.0916, 128]
,[0.9447, 0.5143, 0.9425, 64]
,[0.9447, 0.5143, 0.9425, 32]
,[0.9447, 0.5143, 0.9425, 16]
,[0.9447, 0.5143, 0.9425, 128]
,[0.9447, 0.5143, 0.3126, 64]
,[0.9447, 0.5143, 0.3126, 32]
,[0.9447, 0.5143, 0.3126, 16]
,[0.9447, 0.5143, 0.3126, 128]
,[0.9447, 0.5143, 0.0916, 64]
,[0.9447, 0.5143, 0.0916, 32]
,[0.9447, 0.5143, 0.0916, 16]
,[0.9447, 0.5143, 0.0916, 128]
,[0.6265, 0.7984, 0.9425, 64]
,[0.6265, 0.7984, 0.9425, 32]
,[0.6265, 0.7984, 0.9425, 16]
,[0.6265, 0.7984, 0.9425, 128]
,[0.6265, 0.7984, 0.3126, 64]
,[0.6265, 0.7984, 0.3126, 32]
,[0.6265, 0.7984, 0.3126, 16]
,[0.6265, 0.7984, 0.3126, 128]
,[0.6265, 0.7984, 0.0916, 64]
,[0.6265, 0.7984, 0.0916, 32]
,[0.6265, 0.7984, 0.0916, 16]
,[0.6265, 0.7984, 0.0916, 128]
,[0.6265, 0.5364, 0.9425, 64]
,[0.6265, 0.5364, 0.9425, 32]
,[0.6265, 0.5364, 0.9425, 16]
,[0.6265, 0.5364, 0.9425, 128]
,[0.6265, 0.5364, 0.3126, 64]
,[0.6265, 0.5364, 0.3126, 32]
,[0.6265, 0.5364, 0.3126, 16]
,[0.6265, 0.5364, 0.3126, 128]
,[0.6265, 0.5364, 0.0916, 64]
,[0.6265, 0.5364, 0.0916, 32]
,[0.6265, 0.5364, 0.0916, 16]
,[0.6265, 0.5364, 0.0916, 128]
,[0.6265, 0.5143, 0.9425, 64]
,[0.6265, 0.5143, 0.9425, 32]
,[0.6265, 0.5143, 0.9425, 16]
,[0.6265, 0.5143, 0.9425, 128]
,[0.6265, 0.5143, 0.3126, 64]
,[0.6265, 0.5143, 0.3126, 32]
,[0.6265, 0.5143, 0.3126, 16]
,[0.6265, 0.5143, 0.3126, 128]
,[0.6265, 0.5143, 0.0916, 64]
,[0.6265, 0.5143, 0.0916, 32]
,[0.6265, 0.5143, 0.0916, 16]
,[0.6265, 0.5143, 0.0916, 128]
,[0.146, 0.7984, 0.9425, 64]
,[0.146, 0.7984, 0.9425, 32]
,[0.146, 0.7984, 0.9425, 16]
,[0.146, 0.7984, 0.9425, 128]
,[0.146, 0.7984, 0.3126, 64]
,[0.146, 0.7984, 0.3126, 32]
,[0.146, 0.7984, 0.3126, 16]
,[0.146, 0.7984, 0.3126, 128]
,[0.146, 0.7984, 0.0916, 64]
,[0.146, 0.7984, 0.0916, 32]
,[0.146, 0.7984, 0.0916, 16]
,[0.146, 0.7984, 0.0916, 128]
,[0.146, 0.5364, 0.9425, 64]
,[0.146, 0.5364, 0.9425, 32]
,[0.146, 0.5364, 0.9425, 16]
,[0.146, 0.5364, 0.9425, 128]
,[0.146, 0.5364, 0.3126, 64]
,[0.146, 0.5364, 0.3126, 32]
,[0.146, 0.5364, 0.3126, 16]
,[0.146, 0.5364, 0.3126, 128]
,[0.146, 0.5364, 0.0916, 64]
,[0.146, 0.5364, 0.0916, 32]
,[0.146, 0.5364, 0.0916, 16]
,[0.146, 0.5364, 0.0916, 128]
,[0.146, 0.5143, 0.9425, 64]
,[0.146, 0.5143, 0.9425, 32]
,[0.146, 0.5143, 0.9425, 16]
,[0.146, 0.5143, 0.9425, 128]
,[0.146, 0.5143, 0.3126, 64]
,[0.146, 0.5143, 0.3126, 32]
,[0.146, 0.5143, 0.3126, 16]
,[0.146, 0.5143, 0.3126, 128]
,[0.146, 0.5143, 0.0916, 64]
,[0.146, 0.5143, 0.0916, 32]
,[0.146, 0.5143, 0.0916, 16]
,[0.146, 0.5143, 0.0916, 128]]

# %% [markdown]
# ## Replace

# %%
sequences = New_Sequences(Replace)
Randomized_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Randomized_Search_Results = pd.concat([Randomized_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Randomized_Search_Results.sort_values(by='AUC', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 6
#       4 l1_penalty, l2_penalty, learning_rate, batch_size = params
#       5 try:
# ----> 6     R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
#       7     Randomized_Search_Results = pd.concat([Randomized_Search_Results, pd.DataFrame({
#       8         'Parameters': [str(params)],
#       9         'AUC': [R]
#      10     })], ignore_index=True)
#      11 except Exception as e:
#
# Cell In[17], line 12, in Run_Models(sequences, l1_penalty, l2_penalty, learning_rate, batch_size, skf, Model)
#       6 # loop across the folds
#       7 for i, (train_index, test_index) in enumerate(skf.split(X=[s['X'] for s in sequences], y=[s['Y'] for s in sequences])):
#       8
#       9     # fit the model to the training set
# ---> 12     model.fit(
#      13         sequences=[sequences[i] for i in train_index],
#      14         sequence_length=int(7 * 24 * 60 // 5),
#      15         l1_penalty=l1_penalty,
#      16         l2_penalty=l2_penalty,
#      17         learning_rate=learning_rate,
#      18         batch_size=batch_size,
#      19         epochs=1000,
#      20         seed=42,
#      21         verbose=0
#      22     )
#      24     # evaluate the model on the test set
#      25     metrics = model.evaluate(sequences=[sequences[i] for i in test_index])
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\src\model.py:160, in Model.fit(self, sequences, sequence_length, l1_penalty, l2_penalty, learning_rate, batch_size, epochs, seed, verbose)
#     157 # fit the classifier
#     158 classifier = Classifier()
# --> 160 classifier.fit(
#     161     features=features,
#     162     targets=targets,
#     163     l1_penalty=l1_penalty,
#     164     l2_penalty=l2_penalty,
#     165     learning_rate=learning_rate,
#     166     batch_size=batch_size,
#     167     epochs=epochs,
#     168     seed=seed,
#     169     verbose=verbose
#     170 )
#     172 # save the objects
#     173 self.transformer = transformer
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\src\model.py:90, in Classifier.fit(self, features, targets, l1_penalty, l2_penalty, learning_rate, batch_size, epochs, seed, verbose)
#      84 model.compile(
#      85     optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#      86     loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
#      87 )
#      89 # train the model
# ---> 90 history = model.fit(
#      91     x=features,
#      92     y=targets,
#      93     batch_size=batch_size,
#      94     epochs=epochs,
#      95     shuffle=True,
#      96     validation_split=0.2,
#      97     callbacks=[
#      98         tf.keras.callbacks.EarlyStopping(
#      99             monitor='val_loss',
#     100             patience=10,
#     101             start_from_epoch=100,
#     102             restore_best_weights=True,
#     103         )
#     104     ],
#     105     verbose=verbose,
#     106 )
#     108 # select the threshold
#     109 threshold = get_optimal_threshold(features, targets, model)
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\Mosqu\OneDrive - The University of Texas at Austin\Articulo Giammarino\Hypoglycemia_Analysis\.venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## AIDE

# %%
sequences = New_Sequences(AIDE)
Randomized_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Randomized_Search_Results = pd.concat([Randomized_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Randomized_Search_Results.sort_values(by='AUC', ascending=False)
# Out:
# Error con parámetros [0.01, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.01, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.001, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.01, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 1e-06, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.1, 128]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 64]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 32]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 16]: Model.fit() missing 1 required positional argument: 'self'
# Error con parámetros [0.0001, 0.0001, 0.0001, 128]: Model.fit() missing 1 required positional argument: 'self'
# Empty DataFrame
# Columns: [Parameters, AUC]
# Index: []

# %% [markdown]
# ## Shanghai

# %%
sequences = New_Sequences(Shanghai,minutes=15)
Randomized_Search_Results = pd.DataFrame(columns=['Parameters','AUC'])
for params in Parameters:
    l1_penalty, l2_penalty, learning_rate, batch_size = params
    try:
        R = Run_Models(sequences, l1_penalty,l2_penalty,learning_rate,batch_size, skf, Model)
        Randomized_Search_Results = pd.concat([Randomized_Search_Results, pd.DataFrame({
            'Parameters': [str(params)], 
            'AUC': [R]
        })], ignore_index=True)
    except Exception as e:
        print(f"Error con parámetros {params}: {e}")
        continue
Randomized_Search_Results.sort_values(by='AUC', ascending=False)
# Out:
#                         Parameters       AUC
# 102      [0.0001, 0.0001, 0.1, 16]      0.75
# 54         [0.001, 0.001, 0.1, 16]  0.714286
# 66        [0.001, 0.0001, 0.1, 16]  0.702381
# 7           [0.01, 0.01, 0.1, 128]  0.690476
# 4            [0.01, 0.01, 0.1, 64]  0.690476
# 5            [0.01, 0.01, 0.1, 32]  0.690476
# 42          [0.001, 0.01, 0.1, 16]  0.613095
# 67       [0.001, 0.0001, 0.1, 128]  0.607143
# 64        [0.001, 0.0001, 0.1, 64]  0.607143
# 65        [0.001, 0.0001, 0.1, 32]  0.607143
# 105   [0.0001, 0.0001, 0.0001, 32]  0.595238
# 44       [0.001, 0.01, 0.0001, 64]  0.595238
# 45       [0.001, 0.01, 0.0001, 32]  0.595238
# 47      [0.001, 0.01, 0.0001, 128]  0.595238
# 52         [0.001, 0.001, 0.1, 64]  0.595238
# 53         [0.001, 0.001, 0.1, 32]  0.595238
# 55        [0.001, 0.001, 0.1, 128]  0.595238
# 56      [0.001, 0.001, 0.0001, 64]  0.595238
# 57      [0.001, 0.001, 0.0001, 32]  0.595238
# 59     [0.001, 0.001, 0.0001, 128]  0.595238
# 104   [0.0001, 0.0001, 0.0001, 64]  0.595238
# 95    [0.0001, 0.001, 0.0001, 128]  0.595238
# 68     [0.001, 0.0001, 0.0001, 64]  0.595238
# 69     [0.001, 0.0001, 0.0001, 32]  0.595238
# 35     [0.01, 0.0001, 0.0001, 128]  0.595238
# 80      [0.0001, 0.01, 0.0001, 64]  0.595238
# 81      [0.0001, 0.01, 0.0001, 32]  0.595238
# 83     [0.0001, 0.01, 0.0001, 128]  0.595238
# 88        [0.0001, 0.001, 0.1, 64]  0.595238
# 89        [0.0001, 0.001, 0.1, 32]  0.595238
# 91       [0.0001, 0.001, 0.1, 128]  0.595238
# 92     [0.0001, 0.001, 0.0001, 64]  0.595238
# 93     [0.0001, 0.001, 0.0001, 32]  0.595238
# 71    [0.001, 0.0001, 0.0001, 128]  0.595238
# 107  [0.0001, 0.0001, 0.0001, 128]  0.595238
# 9         [0.01, 0.01, 0.0001, 32]  0.595238
# 8         [0.01, 0.01, 0.0001, 64]  0.595238
# 18          [0.01, 0.001, 0.1, 16]  0.595238
# 20       [0.01, 0.001, 0.0001, 64]  0.595238
# 21       [0.01, 0.001, 0.0001, 32]  0.595238
# 23      [0.01, 0.001, 0.0001, 128]  0.595238
# 33      [0.01, 0.0001, 0.0001, 32]  0.595238
# 32      [0.01, 0.0001, 0.0001, 64]  0.595238
# 11       [0.01, 0.01, 0.0001, 128]  0.595238
# 30         [0.01, 0.0001, 0.1, 16]  0.583333
# 22       [0.01, 0.001, 0.0001, 16]  0.559524
# 90        [0.0001, 0.001, 0.1, 16]  0.559524
# 10        [0.01, 0.01, 0.0001, 16]  0.559524
# 34      [0.01, 0.0001, 0.0001, 16]  0.559524
# 103     [0.0001, 0.0001, 0.1, 128]  0.559524
# 101      [0.0001, 0.0001, 0.1, 32]  0.559524
# 100      [0.0001, 0.0001, 0.1, 64]  0.559524
# 79        [0.0001, 0.01, 0.1, 128]  0.541667
# 77         [0.0001, 0.01, 0.1, 32]  0.541667
# 76         [0.0001, 0.01, 0.1, 64]  0.541667
# 6            [0.01, 0.01, 0.1, 16]   0.52381
# 58      [0.001, 0.001, 0.0001, 16]   0.52381
# 46       [0.001, 0.01, 0.0001, 16]   0.52381
# 70     [0.001, 0.0001, 0.0001, 16]   0.52381
# 31        [0.01, 0.0001, 0.1, 128]  0.494048
# 28         [0.01, 0.0001, 0.1, 64]  0.494048
# 29         [0.01, 0.0001, 0.1, 32]  0.494048
# 94     [0.0001, 0.001, 0.0001, 16]  0.488095
# 106   [0.0001, 0.0001, 0.0001, 16]  0.488095
# 82      [0.0001, 0.01, 0.0001, 16]  0.488095
# 14        [0.01, 0.001, 1e-06, 16]   0.47619
# 84      [0.0001, 0.001, 1e-06, 64]   0.47619
# 85      [0.0001, 0.001, 1e-06, 32]   0.47619
# 86      [0.0001, 0.001, 1e-06, 16]   0.47619
# 99    [0.0001, 0.0001, 1e-06, 128]   0.47619
# 87     [0.0001, 0.001, 1e-06, 128]   0.47619
# 2          [0.01, 0.01, 1e-06, 16]   0.47619
# 3         [0.01, 0.01, 1e-06, 128]   0.47619
# 98     [0.0001, 0.0001, 1e-06, 16]   0.47619
# 13        [0.01, 0.001, 1e-06, 32]   0.47619
# 12        [0.01, 0.001, 1e-06, 64]   0.47619
# 96     [0.0001, 0.0001, 1e-06, 64]   0.47619
# 97     [0.0001, 0.0001, 1e-06, 32]   0.47619
# 15       [0.01, 0.001, 1e-06, 128]   0.47619
# 0          [0.01, 0.01, 1e-06, 64]   0.47619
# 26       [0.01, 0.0001, 1e-06, 16]   0.47619
# 60      [0.001, 0.0001, 1e-06, 64]   0.47619
# 48       [0.001, 0.001, 1e-06, 64]   0.47619
# 49       [0.001, 0.001, 1e-06, 32]   0.47619
# 50       [0.001, 0.001, 1e-06, 16]   0.47619
# 51      [0.001, 0.001, 1e-06, 128]   0.47619
# 1          [0.01, 0.01, 1e-06, 32]   0.47619
# 27      [0.01, 0.0001, 1e-06, 128]   0.47619
# 38        [0.001, 0.01, 1e-06, 16]   0.47619
# 25       [0.01, 0.0001, 1e-06, 32]   0.47619
# 39       [0.001, 0.01, 1e-06, 128]   0.47619
# 24       [0.01, 0.0001, 1e-06, 64]   0.47619
# 61      [0.001, 0.0001, 1e-06, 32]   0.47619
# 62      [0.001, 0.0001, 1e-06, 16]   0.47619
# 63     [0.001, 0.0001, 1e-06, 128]   0.47619
# 37        [0.001, 0.01, 1e-06, 32]   0.47619
# 36        [0.001, 0.01, 1e-06, 64]   0.47619
# 72       [0.0001, 0.01, 1e-06, 64]   0.47619
# 73       [0.0001, 0.01, 1e-06, 32]   0.47619
# 74       [0.0001, 0.01, 1e-06, 16]   0.47619
# 75      [0.0001, 0.01, 1e-06, 128]   0.47619
# 43         [0.001, 0.01, 0.1, 128]  0.416667
# 41          [0.001, 0.01, 0.1, 32]  0.416667
# 40          [0.001, 0.01, 0.1, 64]  0.416667
# 16          [0.01, 0.001, 0.1, 64]  0.410714
# 19         [0.01, 0.001, 0.1, 128]  0.410714
# 17          [0.01, 0.001, 0.1, 32]  0.410714
# 78         [0.0001, 0.01, 0.1, 16]  0.363095
